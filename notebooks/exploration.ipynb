# %% [markdown]
# # TODO:
#
# Projekttitel — et kort navn for jeres projekt
#
# Beskrivelse af programmet — hvad skal programmet kunne? Beskriv det fra brugerens perspektiv
# Data — hvilke data bruger I? Kommer de fra en fil, en API, brugeren selv?
# Relevante teknologier — beskriv kort hvordan I planlægger at bruge følgende i jeres projekt:

# %% [markdown]
# Streamlit
# https://github.com/python-elective-kea/spring2026/tree/master/materialer/streamlit

# %% [markdown]
# Flask eller FastAPI
# https://github.com/python-elective-kea/spring2026/tree/master/materialer/web_frameworks

# %% [markdown]
# Numpy, Pandas og Matplotlib
# https://github.com/python-elective-kea/spring2026/tree/master/materialer/data_science_tools
# https://github.com/python-elective-kea/spring2026/tree/master/materialer/data_science_tools_II

# %% [markdown]
# En LLM API (f.eks. Mistral)
# https://github.com/python-elective-kea/spring2026/tree/master/materialer/mistral-vibe

# %% [markdown]
# Unittests, type checks, code analysis
# https://github.com/python-elective-kea/spring2026/tree/master/materialer/test_lint_code_quality

# %% [markdown]
# Docker Compose
